# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Santosh Kumar Kandukuri**
# Senior Software Engineer

# %% [markdown]
# *I am interested in data science because I interested in analyzing the data and want to derive meaning metrics out of data
# want to see end to end graphical views are presented with raw data*

# %% [markdown]
# ### I want to plot a graph with x and y co-ordinates

# %%
import matplotlib.pyplot as plt
x=[1,2,4]
y=[2,4,1]
plt.plot(x,y)
